# %% [markdown]
# # Introduction to Data Science – Lecture 6 – Exercises
#
# *COMP 5360 / MATH 4100, University of Utah, http://datasciencecourse.net/*

# %% [markdown]
# ## Exercise 1: Reading and Writing Data
#
# The file [grades.csv](grades.csv) is a file with student names and letter grades:
#
# ```
# Alice; A
# Bob; B
# Robert; A
# Richard; C
# ```
#
# Read the file into an array. Add a GPA to the student's row (A=4,B=3,C=2,D=1).
#
# Hint: the function [strip()](https://docs.python.org/3/library/stdtypes.html#str.strip) removes trailing whitespace from a string.
#
# Write that file into a new file `grades_gpa.csv`

# %%
# imports csv library
import csv
# make array
data = []
gpas = {"A":4, "B":3, "C":2, "D":1}
# open file as an array
with open('grades.csv','w') as grades_gpa:
    filereader = csv.reader(grades_gpa, delimiter=',')
    for row in filereader:
        for i in range(len(row)):
            if row[i][-1] == 'A':
                row[i] = row[i]+'; '+str(gpas['A'])
            elif row[i][-1] == 'B':
                row[i] = row[i]+'; '+str(gpas['B'])
            elif row[i][-1] == 'C':
                row[i] = row[i]+'; '+str(gpas['C'])
            elif row[i][-1] == 'D':
                row[i] = row[i]+'; '+str(gpas['D'])
        grades_gpa.write(row+'\n')

### did my best but came up with error on '---> 9    for row in filereader:' saying 'UnsupportedOperation: not readable'
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[1], line 9
#       7 with open('grades.csv','w') as grades_gpa:
#       8     filereader = csv.reader(grades_gpa, delimiter=',')
# ----> 9     for row in filereader:
#      10         for i in range(len(row)):
#      11             if row[i][-1] == 'A':
#
# UnsupportedOperation: not readable

# %% [markdown]
# ## Exercise 2: Data Frames
#
# * Calculate the mean certified sales for all albums.

# %%
import pandas as pd
hit_albums = pd.read_csv("hit_albums.csv")

# %%
hit_albums.describe() # mean displayed is 1988.662338
# Out:
#           Released  Certified sales (millions)  Claimed sales (millions)
# count    77.000000                   77.000000                 31.000000
# mean   1988.662338                   22.409091                 35.354839
# std       9.949359                    4.521620                  7.855140
# min    1967.000000                   13.100000                 30.000000
# 25%    1983.000000                   20.000000                 30.000000
# 50%    1987.000000                   20.600000                 32.000000
# 75%    1996.000000                   25.000000                 39.500000
# max    2015.000000                   45.400000                 65.000000

# %% [markdown]
#  * Create a new dataframe that only contains albums with more than 20 million certified sales.

# %%
mask = hit_albums['Certified sales (millions)']>20
hit_albums.loc[mask]
# Out:
#                                Artist  \
# 0                     Michael Jackson
# 1                               AC/DC
# 2                          Pink Floyd
# 3   Whitney Houston / Various artists
# 4                           Meat Loaf
# 5                              Eagles
# 7                       Fleetwood Mac
# 8                        Shania Twain
# 9                        Led Zeppelin
# 10                    Michael Jackson
# 11                  Alanis Morissette
# 12                        Celine Dion
# 14                             Eagles
# 19                        The Beatles
# 20                              Adele
# 29                            Santana
# 30                      Guns N' Roses
# 31                               ABBA
# 32                           Bon Jovi
# 33                        Spice Girls
# 34                    Various artists
# 35                     Britney Spears
# 36                        Linkin Park
# 37           Bob Marley & The Wailers
# 38                        Carole King
# 39                            Madonna
# 40                            Madonna
# 41                       Mariah Carey
# 42                        Norah Jones
# 43                       Phil Collins
# 44                              Queen
# 45                  Simon & Garfunkel
# 46                                 U2
# 47                    Whitney Houston
# 48                    Backstreet Boys
# 49                    Backstreet Boys
# 50                        Ace of Base
# 51                                TLC
# 52                       Cyndi Lauper
# 53                              Oasis
# 54                           Bon Jovi
# 55                             Eminem
#
#                                                 Album  Released  \
# 0                                            Thriller      1982
# 1                                       Back in Black      1980
# 2                           The Dark Side of the Moon      1973
# 3                                       The Bodyguard      1992
# 4                                     Bat Out of Hell      1977
# 5                     Their Greatest Hits (1971–1975)      1976
# 7                                             Rumours      1977
# 8                                        Come On Over      1997
# 9                                     Led Zeppelin IV      1971
# 10                                                Bad      1987
# 11                                 Jagged Little Pill      1995
# 12                                   Falling into You      1996
# 14                                   Hotel California      1976
# 19                                                  1      2000
# 20                                                 21      2011
# 29                                       Supernatural      1999
# 30                           Appetite for Destruction      1987
# 31                                Gold: Greatest Hits      1992
# 32                                  Slippery When Wet      1986
# 33                                              Spice      1996
# 34  Grease: The Original Soundtrack from the Motio...      1978
# 35                              ...Baby One More Time      1999
# 36                                      Hybrid Theory      2000
# 37       Legend: The Best of Bob Marley & The Wailers      1984
# 38                                           Tapestry      1971
# 39                                      Like a Virgin      1984
# 40                                          True Blue      1986
# 41                                           Daydream      1995
# 42                                  Come Away with Me      2002
# 43                                 No Jacket Required      1985
# 44                                      Greatest Hits      1981
# 45                         Bridge over Troubled Water      1970
# 46                                    The Joshua Tree      1987
# 47                                    Whitney Houston      1985
# 48                Backstreet's Back / Backstreet Boys      1997
# 49                                         Millennium      1999
# 50                              Happy Nation/The Sign      1993
# 51                                      CrazySexyCool      1994
# 52                                   She's So Unusual      1983
# 53                  (What's the Story) Morning Glory?      1995
# 54                                         Cross Road      1994
# 55                            The Marshall Mathers LP      2000
#
#                                      Genre  Certified sales (millions)  \
# 0                           Pop, rock, R&B                        45.4
# 1                                Hard rock                        25.9
# 2                         Progressive rock                        22.7
# 3                Soundtrack/R&B, soul, pop                        27.4
# 4              Hard rock, progressive rock                        20.6
# 5               Rock, soft rock, folk rock                        32.2
# 7                                Soft rock                        27.9
# 8                             Country, pop                        29.6
# 9                   Hard rock, heavy metal                        29.0
# 10                         Pop, funk, rock                        20.3
# 11                        Alternative rock                        24.8
# 12                          Pop, Soft rock                        20.2
# 14              Rock, soft rock, folk rock                        21.5
# 19                                    Rock                        21.6
# 20                               Pop, soul                        22.3
# 29                                    Rock                        20.5
# 30                  Heavy metal, hard rock                        21.3
# 31                                     Pop                        29.0
# 32                               Hard rock                        28.0
# 33                                     Pop                        28.0
# 34                              Soundtrack                        28.0
# 35                                     Pop                        28.0
# 36  Nu metal, rap metal, alternative metal                        27.0
# 37                                  Reggae                        25.0
# 38                                     Pop                        25.0
# 39                              Pop, dance                        25.0
# 40                                     Pop                        25.0
# 41                                Pop, R&B                        25.0
# 42                                    Jazz                        25.0
# 43                               Pop, Rock                        25.0
# 44                                    Rock                        25.0
# 45                               Folk rock                        25.0
# 46                                    Rock                        25.0
# 47                                Pop, R&B                        25.0
# 48                                     Pop                        24.0
# 49                                     Pop                        24.0
# 50                                     Pop                        23.0
# 51                            R&B, hip hop                        23.0
# 52            New wave, pop rock, synthpop                        22.0
# 53                           Britpop, rock                        22.0
# 54                               Hard rock                        21.0
# 55                            Rap, hip-hop                        21.0
#
#     Claimed sales (millions)
# 0                       65.0
# 1                       50.0
# 2                       45.0
# 3                       44.0
# 4                       43.0
# 5                       42.0
# 7                       40.0
# 8                       39.0
# 9                       37.0
# 10                      34.0
# 11                      33.0
# 12                      32.0
# 14                      32.0
# 19                      31.0
# 20                      30.0
# 29                      30.0
# 30                      30.0
# 31                       NaN
# 32                       NaN
# 33                       NaN
# 34                       NaN
# 35                       NaN
# 36                       NaN
# 37                       NaN
# 38                       NaN
# 39                       NaN
# 40                       NaN
# 41                       NaN
# 42                       NaN
# 43                       NaN
# 44                       NaN
# 45                       NaN
# 46                       NaN
# 47                       NaN
# 48                       NaN
# 49                       NaN
# 50                       NaN
# 51                       NaN
# 52                       NaN
# 53                       NaN
# 54                       NaN
# 55                       NaN

# %% [markdown]
#  * Create a new dataframe based on the hit_albums dataset that only contains the artists that have at least two albums in the list.

# %%
# get count of artist indexes
grouped = hit_albums.groupby('Artist')
album_count = grouped.count().sort_values('Certified sales (millions)', ascending=False)
album_count['Count'] = album_count['Album']>=2

# display the artists that have >=2 albums
mask = album_count['Count']==True
album_count.loc[mask]
# Out:
#                  Album  Released  Genre  Certified sales (millions)  \
# Artist
# Michael Jackson      5         5      5                           5
# Various artists      3         3      3                           3
# Madonna              3         3      3                           3
# Shania Twain         3         3      3                           3
# The Beatles          3         3      3                           3
# Pink Floyd           2         2      2                           2
# Whitney Houston      2         2      2                           2
# Adele                2         2      2                           2
# Mariah Carey         2         2      2                           2
# Backstreet Boys      2         2      2                           2
# Bon Jovi             2         2      2                           2
# Eagles               2         2      2                           2
# Britney Spears       2         2      2                           2
# Celine Dion          2         2      2                           2
#
#                  Claimed sales (millions)  Count
# Artist
# Michael Jackson                         3   True
# Various artists                         1   True
# Madonna                                 1   True
# Shania Twain                            1   True
# The Beatles                             3   True
# Pink Floyd                              2   True
# Whitney Houston                         0   True
# Adele                                   1   True
# Mariah Carey                            1   True
# Backstreet Boys                         0   True
# Bon Jovi                                0   True
# Eagles                                  2   True
# Britney Spears                          0   True
# Celine Dion                             2   True

# %% [markdown]
# * Create a new dataframe that contains the aggregates sum of all certified sales for each year.

# %%
grouped.agg(sum)
# Out:
#                                                                                Album  \
# Artist
# ABBA                                                             Gold: Greatest Hits
# AC/DC                                                                  Back in Black
# Ace of Base                                                    Happy Nation/The Sign
# Adele                                                                           2125
# Alanis Morissette                                                 Jagged Little Pill
# Avril Lavigne                                                                 Let Go
# Backstreet Boys                        Backstreet's Back / Backstreet BoysMillennium
# Bee Gees / Various artists                                      Saturday Night Fever
# Bob Marley & The Wailers                Legend: The Best of Bob Marley & The Wailers
# Bon Jovi                                                 Slippery When WetCross Road
# Boston                                                                        Boston
# Britney Spears                          ...Baby One More TimeOops!... I Did It Again
# Bruce Springsteen                                                 Born in the U.S.A.
# Carole King                                                                 Tapestry
# Celine Dion                                    Falling into YouLet's Talk About Love
# Cyndi Lauper                                                        She's So Unusual
# Def Leppard                                                                 Hysteria
# Dire Straits                                                        Brothers in Arms
# Eagles                               Their Greatest Hits (1971–1975)Hotel California
# Eminem                                                       The Marshall Mathers LP
# Eric Clapton                                                               Unplugged
# Fleetwood Mac                                                                Rumours
# George Michael                                                                 Faith
# Green Day                                                                     Dookie
# Guns N' Roses                                               Appetite for Destruction
# James Horner                                  Titanic: Music from the Motion Picture
# Led Zeppelin                                                         Led Zeppelin IV
# Linkin Park                                                            Hybrid Theory
# Lionel Richie                                                        Can't Slow Down
# Madonna                              The Immaculate CollectionLike a VirginTrue Blue
# Mariah Carey                                                       Music BoxDaydream
# Meat Loaf                                                            Bat Out of Hell
# Metallica                                                                  Metallica
# Michael Jackson                    ThrillerBadDangerousHIStory: Past, Present and...
# Nirvana                                                                    Nevermind
# Norah Jones                                                        Come Away with Me
# Oasis                                              (What's the Story) Morning Glory?
# Phil Collins                                                      No Jacket Required
# Pink Floyd                                         The Dark Side of the MoonThe Wall
# Prince & the Revolution                                                  Purple Rain
# Queen                                                                  Greatest Hits
# Santana                                                                 Supernatural
# Shakira                                                              Laundry Service
# Shania Twain                                          Come On OverThe Woman in MeUp!
# Simon & Garfunkel                                         Bridge over Troubled Water
# Spice Girls                                                                    Spice
# Supertramp                                                      Breakfast in America
# TLC                                                                    CrazySexyCool
# The Beatles                         Sgt. Pepper's Lonely Hearts Club Band1Abbey Road
# Tina Turner                                                           Private Dancer
# Tracy Chapman                                                          Tracy Chapman
# U2                                                                   The Joshua Tree
# Usher                                                                    Confessions
# Various artists                    Dirty DancingGrease: The Original Soundtrack f...
# Whitney Houston                                               Whitney HoustonWhitney
# Whitney Houston / Various artists                                      The Bodyguard
#
#                                    Released  \
# Artist
# ABBA                                   1992
# AC/DC                                  1980
# Ace of Base                            1993
# Adele                                  4026
# Alanis Morissette                      1995
# Avril Lavigne                          2002
# Backstreet Boys                        3996
# Bee Gees / Various artists             1977
# Bob Marley & The Wailers               1984
# Bon Jovi                               3980
# Boston                                 1976
# Britney Spears                         3999
# Bruce Springsteen                      1984
# Carole King                            1971
# Celine Dion                            3993
# Cyndi Lauper                           1983
# Def Leppard                            1987
# Dire Straits                           1985
# Eagles                                 3952
# Eminem                                 2000
# Eric Clapton                           1992
# Fleetwood Mac                          1977
# George Michael                         1987
# Green Day                              1994
# Guns N' Roses                          1987
# James Horner                           1997
# Led Zeppelin                           1971
# Linkin Park                            2000
# Lionel Richie                          1983
# Madonna                                5960
# Mariah Carey                           3988
# Meat Loaf                              1977
# Metallica                              1991
# Michael Jackson                        9934
# Nirvana                                1991
# Norah Jones                            2002
# Oasis                                  1995
# Phil Collins                           1985
# Pink Floyd                             3952
# Prince & the Revolution                1984
# Queen                                  1981
# Santana                                1999
# Shakira                                2001
# Shania Twain                           5994
# Simon & Garfunkel                      1970
# Spice Girls                            1996
# Supertramp                             1979
# TLC                                    1994
# The Beatles                            5936
# Tina Turner                            1984
# Tracy Chapman                          1988
# U2                                     1987
# Usher                                  2004
# Various artists                        5948
# Whitney Houston                        3972
# Whitney Houston / Various artists      1992
#
#                                                                                Genre  \
# Artist
# ABBA                                                                             Pop
# AC/DC                                                                      Hard rock
# Ace of Base                                                                      Pop
# Adele                                                        Pop, soulSoul, pop, R&B
# Alanis Morissette                                                   Alternative rock
# Avril Lavigne                                Pop rock, alternative rock, post-grunge
# Backstreet Boys                                                               PopPop
# Bee Gees / Various artists                                                     Disco
# Bob Marley & The Wailers                                                      Reggae
# Bon Jovi                                                          Hard rockHard rock
# Boston                                                                     Hard rock
# Britney Spears                                                                PopPop
# Bruce Springsteen                                                               Rock
# Carole King                                                                      Pop
# Celine Dion                                             Pop, Soft rockPop, Soft rock
# Cyndi Lauper                                            New wave, pop rock, synthpop
# Def Leppard                                                           Pop, Hard rock
# Dire Straits                                                                    Rock
# Eagles                             Rock, soft rock, folk rockRock, soft rock, fol...
# Eminem                                                                  Rap, hip-hop
# Eric Clapton                                               Acoustic blues, folk rock
# Fleetwood Mac                                                              Soft rock
# George Michael                                                              Pop, R&B
# Green Day                                      Pop punk, punk rock, alternative rock
# Guns N' Roses                                                 Heavy metal, hard rock
# James Horner                                                              Soundtrack
# Led Zeppelin                                                  Hard rock, heavy metal
# Linkin Park                                   Nu metal, rap metal, alternative metal
# Lionel Richie                                                         Pop, R&B, soul
# Madonna                                                      Pop, DancePop, dancePop
# Mariah Carey                                                  Pop, R&B, RockPop, R&B
# Meat Loaf                                                Hard rock, progressive rock
# Metallica                                                  Thrash metal, heavy metal
# Michael Jackson                    Pop, rock, R&BPop, funk, rockRock, Funk, PopPo...
# Nirvana                                                     Grunge, alternative rock
# Norah Jones                                                                     Jazz
# Oasis                                                                  Britpop, rock
# Phil Collins                                                               Pop, Rock
# Pink Floyd                                          Progressive rockProgressive rock
# Prince & the Revolution                                               Pop, rock, R&B
# Queen                                                                           Rock
# Santana                                                                         Rock
# Shakira                                                                    Pop, Rock
# Shania Twain                       Country, popCountry, popCountry, pop, world music
# Simon & Garfunkel                                                          Folk rock
# Spice Girls                                                                      Pop
# Supertramp                                                Progressive rock, art rock
# TLC                                                                     R&B, hip hop
# The Beatles                                                             RockRockRock
# Tina Turner                                                           Pop, rock, R&B
# Tracy Chapman                                                              Folk rock
# U2                                                                              Rock
# Usher                                                                            R&B
# Various artists                                   Pop, rock, R&BSoundtrackSoundtrack
# Whitney Houston                                                     Pop, R&BPop, R&B
# Whitney Houston / Various artists                          Soundtrack/R&B, soul, pop
#
#                                    Certified sales (millions)  \
# Artist
# ABBA                                                     29.0
# AC/DC                                                    25.9
# Ace of Base                                              23.0
# Adele                                                    42.3
# Alanis Morissette                                        24.8
# Avril Lavigne                                            20.0
# Backstreet Boys                                          48.0
# Bee Gees / Various artists                               19.0
# Bob Marley & The Wailers                                 25.0
# Bon Jovi                                                 49.0
# Boston                                                   20.0
# Britney Spears                                           48.0
# Bruce Springsteen                                        19.6
# Carole King                                              25.0
# Celine Dion                                              39.5
# Cyndi Lauper                                             22.0
# Def Leppard                                              20.0
# Dire Straits                                             17.7
# Eagles                                                   53.7
# Eminem                                                   21.0
# Eric Clapton                                             20.0
# Fleetwood Mac                                            27.9
# George Michael                                           20.0
# Green Day                                                20.0
# Guns N' Roses                                            21.3
# James Horner                                             18.1
# Led Zeppelin                                             29.0
# Linkin Park                                              27.0
# Lionel Richie                                            20.0
# Madonna                                                  69.4
# Mariah Carey                                             44.0
# Meat Loaf                                                20.6
# Metallica                                                19.9
# Michael Jackson                                         123.3
# Nirvana                                                  16.7
# Norah Jones                                              25.0
# Oasis                                                    22.0
# Phil Collins                                             25.0
# Pink Floyd                                               40.3
# Prince & the Revolution                                  20.0
# Queen                                                    25.0
# Santana                                                  20.5
# Shakira                                                  20.0
# Shania Twain                                             69.6
# Simon & Garfunkel                                        25.0
# Spice Girls                                              28.0
# Supertramp                                               20.0
# TLC                                                      23.0
# The Beatles                                              49.1
# Tina Turner                                              20.0
# Tracy Chapman                                            20.0
# U2                                                       25.0
# Usher                                                    20.0
# Various artists                                          65.9
# Whitney Houston                                          45.0
# Whitney Houston / Various artists                        27.4
#
#                                    Claimed sales (millions)
# Artist
# ABBA                                                    0.0
# AC/DC                                                  50.0
# Ace of Base                                             0.0
# Adele                                                  30.0
# Alanis Morissette                                      33.0
# Avril Lavigne                                           0.0
# Backstreet Boys                                         0.0
# Bee Gees / Various artists                             40.0
# Bob Marley & The Wailers                                0.0
# Bon Jovi                                                0.0
# Boston                                                  0.0
# Britney Spears                                          0.0
# Bruce Springsteen                                      30.0
# Carole King                                             0.0
# Celine Dion                                            63.0
# Cyndi Lauper                                            0.0
# Def Leppard                                             0.0
# Dire Straits                                           30.0
# Eagles                                                 74.0
# Eminem                                                  0.0
# Eric Clapton                                            0.0
# Fleetwood Mac                                          40.0
# George Michael                                          0.0
# Green Day                                               0.0
# Guns N' Roses                                          30.0
# James Horner                                           30.0
# Led Zeppelin                                           37.0
# Linkin Park                                             0.0
# Lionel Richie                                           0.0
# Madonna                                                30.0
# Mariah Carey                                           32.0
# Meat Loaf                                              43.0
# Metallica                                              30.0
# Michael Jackson                                       131.0
# Nirvana                                                30.0
# Norah Jones                                             0.0
# Oasis                                                   0.0
# Phil Collins                                            0.0
# Pink Floyd                                             75.0
# Prince & the Revolution                                 0.0
# Queen                                                   0.0
# Santana                                                30.0
# Shakira                                                 0.0
# Shania Twain                                           39.0
# Simon & Garfunkel                                       0.0
# Spice Girls                                             0.0
# Supertramp                                              0.0
# TLC                                                     0.0
# The Beatles                                            93.0
# Tina Turner                                             0.0
# Tracy Chapman                                           0.0
# U2                                                      0.0
# Usher                                                   0.0
# Various artists                                        32.0
# Whitney Houston                                         0.0
# Whitney Houston / Various artists                      44.0
